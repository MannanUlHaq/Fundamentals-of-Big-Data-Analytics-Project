# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=5044a87da9967eabeb5b235b12cb28b11aadf62fc9cf1881751edfae17b4bad5
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession

conf = SparkConf().setAppName("Project").setMaster("local")

sc = SparkContext.getOrCreate(conf = conf)
spark = SparkSession(sc)

# Read data from CSV file into Spark DataFrame
data = spark.read.csv("recipes_combined.csv", header=True,inferSchema=True)
data.show()

# Get column names of the DataFrame
Col = data.columns
print(Col)

# Drop specified columns from the DataFrame
columns_to_drop = ['_c2', '_c3', '_c4', '_c5', '_c6', '_c7', '_c8', '_c9', '_c10', '_c11', '_c12', '_c13', '_c14', '_c15','all_ingredients']
Filter_data = data.drop(*columns_to_drop)
Filter_data.show(truncate = False)

# Replace certain characters in the 'ingredients' column of the DataFrame
from pyspark.sql.functions import regexp_replace

filtered_data = Filter_data.withColumn('ingredients', regexp_replace('ingredients', '//', ' ')) \
    .withColumn('ingredients', regexp_replace('ingredients', '[(|)]', ''))
filtered_data.show(truncate = False)

from pyspark.ml.feature import Tokenizer, HashingTF, IDF
from pyspark.ml import Pipeline
from pyspark.sql.functions import col

# Tokenize the 'ingredients' column
tokenizer = Tokenizer(inputCol="ingredients", outputCol="words")

# Apply HashingTF to convert tokenized words into feature vectors
hashingTF = HashingTF(inputCol="words", outputCol="rawFeatures")

# Apply IDF to the feature vectors
idf = IDF(inputCol="rawFeatures", outputCol="features")

# Create a pipeline to execute the above operations sequentially
pipeline = Pipeline(stages=[tokenizer,hashingTF, idf])
pipeline_model = pipeline.fit(filtered_data)
transformed_data = pipeline_model.transform(filtered_data)

transformed_data.show()

# Drop unnecessary columns from the DataFrame
columns_to_drop = ['ingredients','_c2', '_c3', '_c4', '_c5', '_c6', '_c7', '_c8', '_c9', '_c10', '_c11', '_c12', '_c13', '_c14', '_c15','all_ingredients','words','rawFeatures']
Filter_data = transformed_data.drop(*columns_to_drop)
Filter_data.show(truncate = False)

from pyspark.ml.linalg import Vectors
from pyspark.sql.functions import udf
from pyspark.sql.types import DoubleType

# Define a function to calculate cosine similarity between two vectors
def cosine_similarity(vec1, vec2):
    dot_product = float(vec1.dot(vec2))
    norm_vec1 = float(vec1.norm(2))
    norm_vec2 = float(vec2.norm(2))
    return dot_product / (norm_vec1 * norm_vec2)

# Register the cosine similarity function as a User Defined Function (UDF)
cosine_similarity_udf = udf(cosine_similarity, DoubleType())

# Perform cross join between two copies of the DataFrame
joined_data = Filter_data.alias("df1").crossJoin(Filter_data.alias("df2"))

# Calculate cosine similarity between each pair of recipes
cosine_similarity_result = joined_data.select(
    "df1.recipeNames",
    "df2.recipeNames",
    cosine_similarity_udf("df1.features", "df2.features").alias("cosine_similarity")
)

# Filter out pairs with the same recipe names to avoid self-similarity
cosine_similarity_result = cosine_similarity_result.filter("df1.recipeNames != df2.recipeNames")

# Show the final DataFrame containing cosine similarity scores
cosine_similarity_result.show(truncate = False)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+----+----+----+----+----+----+----+----+----+----+----+--------------------+
# |         recipeNames|         ingredients|                 _c2|                 _c3|                 _c4| _c5| _c6| _c7| _c8| _c9|_c10|_c11|_c12|_c13|_c14|_c15|     all_ingredients|
# +--------------------+--------------------+--------------------+--------------------+--------------------+----+----+----+----+----+----+----+----+----+----+----+--------------------+
# |Poppy Seed Bread ...|3 cups all-purpos...|                NULL|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Poppy Seed Bread ...|
# |Czech Christmas H...|1 (0.6 ounce) cak...|beaten // 1 teasp...|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Czech Christmas H...|
# |  Applesauce Bread I|3 cups all-purpos...|                NULL|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Applesauce Bread ...|
# |  Raisin Brown Bread|2 cups boiling wa...|                NULL|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Raisin Brown Brea...|
# |Applesauce Raisin...|1 1/2 cups all-pu...|beaten // 1/4 cup...|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Applesauce Raisin...|
# |  Apple Raisin Bread|1 1/2 cups all-pu...|                NULL|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Apple Raisin Brea...|
# |Buttermilk Oatmea...|1 cup rolled oats...|                NULL|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Buttermilk Oatmea...|
# |         Kolaches II|1 cup shortening ...|beaten // 1/2 tea...|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Kolaches II //  1...|
# |Whole Wheat Bread II|1/3 cup shortenin...|                NULL|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Whole Wheat Bread...|
# |       Finnish Pulla|2 cups milk // 1/...|beaten // 9 cups ...|     melted // 1 egg|beaten // 2 table...|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Finnish Pulla // ...|
# |Chinese Steamed Buns|1 tablespoon acti...|                NULL|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Chinese Steamed B...|
# |Cottage Cheese Br...|3/4 cup warm wate...|room temperature ...|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Cottage Cheese Br...|
# |Mocha Chocolate C...|1 cup margarine /...|dissolved in // 1...|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Mocha Chocolate C...|
# |Ruby's Special Co...|1 cup cornmeal //...|drained // 1 (4 o...|drained // 1/2 cu...|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Ruby's Special Co...|
# |       Maple Muffins|1 1/2 cups all-pu...|beaten // 1/2 cup...|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Maple Muffins // ...|
# |      French Toast I|6 thick slices br...|                NULL|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|French Toast I //...|
# |Snow Day French T...|2 eggs // 1/2 cup...|                NULL|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Snow Day French T...|
# |   Angel Biscuits II|1 (.25 ounce) pac...|                NULL|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Angel Biscuits II...|
# |Fudgy Chocolate C...|1/2 cup applesauc...|softened // 1/2 c...|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Fudgy Chocolate C...|
# |Pumpernickel Brea...|2 cups warm milk ...|                NULL|                NULL|                NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|NULL|Pumpernickel Brea...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+----+----+----+----+----+----+----+----+----+----+----+--------------------+
# only showing top 20 rows
#
# ['recipeNames', 'ingredients', '_c2', '_c3', '_c4', '_c5', '_c6', '_c7', '_c8', '_c9', '_c10', '_c11', '_c12', '_c13', '_c14', '_c15', 'all_ingredients']
# +-----------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |recipeNames                        |ingredients                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# +-----------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Poppy Seed Bread with Glaze        |3 cups all-purpose flour // 1 1/2 teaspoons salt // 1 1/2 teaspoons baking powder // 3 tablespoons poppy seeds // 1 1/2 teaspoons butter flavored extract // 1 1/3 cups vegetable oil // 3 eggs // 1 1/2 cups milk // 2 1/4 cups white sugar // 1 1/2 teaspoons vanilla extract // 1 1/2 teaspoons almond extract // 1/4 cup orange juice // 1/2 teaspoon butter flavored extract // 1/2 teaspoon almond extract // 1 teaspoon vanilla extract // 2 cups confectioners' sugar //|
# |Czech Christmas Hoska              |1 (0.6 ounce) cake compressed fresh yeast // 1/4 cup warm water (110 degrees F/45 degrees C) // 1/2 cup white sugar // 1/2 cup butter // 1 egg                                                                                                                                                                                                                                                                                                                                  |
# |Applesauce Bread I                 |3 cups all-purpose flour // 3 eggs // 2 cups white sugar // 1 cup vegetable oil // 2 cups applesauce // 1 cup raisins (optional) // 1 teaspoon ground cinnamon // 1 teaspoon baking soda // 1/4 teaspoon baking powder // 1/2 cup sour cream //                                                                                                                                                                                                                                 |
# |Raisin Brown Bread                 |2 cups boiling water // 1 cup rolled oats // 2 tablespoons shortening // 3 tablespoons brown sugar // 4 teaspoons salt // 1 cup molasses // 1/2 cup warm water (110 degrees F/45 degrees C) // 1 teaspoon white sugar // 2 tablespoons active dry yeast // 3 cups warm water (110 degrees F/45 degrees C) // 12 cups bread flour // 1 1/2 cups raisins // 1 1/2 teaspoons ground cinnamon //                                                                                    |
# |Applesauce Raisin Bread            |1 1/2 cups all-purpose flour // 1 1/2 teaspoons baking powder // 1/2 teaspoon baking soda // 1 1/2 teaspoons ground cinnamon // 1 cup quick cooking oats // 3/4 cup packed brown sugar // 3/4 cup raisins // 1 1/4 cups applesauce // 1/3 cup vegetable oil // 2 eggs                                                                                                                                                                                                           |
# |Apple Raisin Bread                 |1 1/2 cups all-purpose flour // 2 teaspoons baking powder // 1/4 teaspoon baking soda // 1 teaspoon salt // 1 1/4 teaspoons ground cinnamon // 1/4 teaspoon ground nutmeg // 2/3 cup packed brown sugar // 1 cup rolled oats // 1 1/2 cups grated apple // 1/4 cup chopped walnuts // 1/4 cup raisins // 2 eggs // 1/4 cup milk // 1/4 cup vegetable oil //                                                                                                                     |
# |Buttermilk Oatmeal Bread           |1 cup rolled oats // 1 cup buttermilk // 1/2 cup vegetable oil // 1 egg // 1/2 cup packed brown sugar // 1 cup all-purpose flour // 1 teaspoon baking powder // 1/2 teaspoon baking soda // 1/2 teaspoon salt //                                                                                                                                                                                                                                                                |
# |Kolaches II                        |1 cup shortening // 1/2 cup white sugar // 1 1/2 teaspoons salt // 2 1/2 cups scalded milk // 4 egg yolks                                                                                                                                                                                                                                                                                                                                                                       |
# |Whole Wheat Bread II               |1/3 cup shortening // 1 cup hot water // 1 cup packed brown sugar // 3 (.25 ounce) packages active dry yeast // 4 cups warm water (110 degrees F/45 degrees C) // 4 tablespoons white sugar // 4 teaspoons salt // 6 cups bread flour // 6 cups whole wheat flour //                                                                                                                                                                                                            |
# |Finnish Pulla                      |2 cups milk // 1/2 cup warm water (110 degrees F/45 degrees C) // 1 (.25 ounce) package active dry yeast // 1 cup white sugar // 1 teaspoon salt // 1 teaspoon ground cardamom // 4 eggs                                                                                                                                                                                                                                                                                        |
# |Chinese Steamed Buns               |1 tablespoon active dry yeast // 1 teaspoon white sugar // 1/4 cup all-purpose flour // 1/4 cup water // 1/2 cup warm water // 1 1/2 cups all-purpose flour // 1/4 teaspoon salt // 2 tablespoons white sugar // 1 tablespoon vegetable oil // 1/2 teaspoon baking powder //                                                                                                                                                                                                    |
# |Cottage Cheese Bread II            |3/4 cup warm water (110 degrees F/45 degrees C) // 1 cup cottage cheese                                                                                                                                                                                                                                                                                                                                                                                                         |
# |Mocha Chocolate Chip Banana Muffins|1 cup margarine // 1 1/4 cups white sugar // 1 egg // 3 ripe bananas // 1 tablespoon instant coffee granules                                                                                                                                                                                                                                                                                                                                                                    |
# |Ruby's Special Cornbread           |1 cup cornmeal // 1 cup milk // 3 eggs // 1/2 cup chopped green bell pepper // 1/2 cup chopped onion // 1 teaspoon garlic powder // 1/2 teaspoon salt // 1/2 teaspoon baking soda // 1/2 teaspoon white sugar // 1 (8.75 ounce) can whole kernel corn                                                                                                                                                                                                                           |
# |Maple Muffins                      |1 1/2 cups all-purpose flour // 1/4 cup white sugar // 2 teaspoons baking powder // 1/2 teaspoon salt // 1/4 cup shortening // 1/4 cup rolled oats // 1 egg                                                                                                                                                                                                                                                                                                                     |
# |French Toast I                     |6 thick slices bread // 2 eggs // 2/3 cup milk // 1/4 teaspoon ground cinnamon (optional) // 1/4 teaspoon ground nutmeg (optional) // 1 teaspoon vanilla extract (optional) // salt to taste //                                                                                                                                                                                                                                                                                 |
# |Snow Day French Toast              |2 eggs // 1/2 cup milk // 1/4 teaspoon salt // 1/2 teaspoon ground nutmeg // 6 slices raisin bread // 2 tablespoons butter // 1 cup white sugar //                                                                                                                                                                                                                                                                                                                              |
# |Angel Biscuits II                  |1 (.25 ounce) package active dry yeast // 1/4 cup warm water (110 degrees F/45 degrees C) // 2 cups buttermilk // 5 cups all-purpose flour // 1 tablespoon baking powder // 1 teaspoon baking soda // 2 teaspoons salt // 3 tablespoons white sugar // 3/4 cup shortening //                                                                                                                                                                                                    |
# |Fudgy Chocolate Chip Muffins       |1/2 cup applesauce // 1/4 cup margarine                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |Pumpernickel Bread II              |2 cups warm milk // 2 tablespoons vegetable oil // 4 tablespoons molasses // 3 1/4 cups bread flour // 1 1/3 cups rye flour // 1/2 cup cornmeal // 1 1/3 teaspoons salt // 2 2/3 teaspoons active dry yeast // 4 tablespoons unsweetened cocoa powder // 2 2/3 tablespoons brown sugar //                                                                                                                                                                                       |
# +-----------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
#
# +-----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |recipeNames                        |ingredients                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# +-----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Poppy Seed Bread with Glaze        |3 cups all-purpose flour   1 1/2 teaspoons salt   1 1/2 teaspoons baking powder   3 tablespoons poppy seeds   1 1/2 teaspoons butter flavored extract   1 1/3 cups vegetable oil   3 eggs   1 1/2 cups milk   2 1/4 cups white sugar   1 1/2 teaspoons vanilla extract   1 1/2 teaspoons almond extract   1/4 cup orange juice   1/2 teaspoon butter flavored extract   1/2 teaspoon almond extract   1 teaspoon vanilla extract   2 cups confectioners' sugar  |
# |Czech Christmas Hoska              |1 0.6 ounce cake compressed fresh yeast   1/4 cup warm water 110 degrees F/45 degrees C   1/2 cup white sugar   1/2 cup butter   1 egg                                                                                                                                                                                                                                                                                                                          |
# |Applesauce Bread I                 |3 cups all-purpose flour   3 eggs   2 cups white sugar   1 cup vegetable oil   2 cups applesauce   1 cup raisins optional   1 teaspoon ground cinnamon   1 teaspoon baking soda   1/4 teaspoon baking powder   1/2 cup sour cream                                                                                                                                                                                                                               |
# |Raisin Brown Bread                 |2 cups boiling water   1 cup rolled oats   2 tablespoons shortening   3 tablespoons brown sugar   4 teaspoons salt   1 cup molasses   1/2 cup warm water 110 degrees F/45 degrees C   1 teaspoon white sugar   2 tablespoons active dry yeast   3 cups warm water 110 degrees F/45 degrees C   12 cups bread flour   1 1/2 cups raisins   1 1/2 teaspoons ground cinnamon                                                                                       |
# |Applesauce Raisin Bread            |1 1/2 cups all-purpose flour   1 1/2 teaspoons baking powder   1/2 teaspoon baking soda   1 1/2 teaspoons ground cinnamon   1 cup quick cooking oats   3/4 cup packed brown sugar   3/4 cup raisins   1 1/4 cups applesauce   1/3 cup vegetable oil   2 eggs                                                                                                                                                                                                    |
# |Apple Raisin Bread                 |1 1/2 cups all-purpose flour   2 teaspoons baking powder   1/4 teaspoon baking soda   1 teaspoon salt   1 1/4 teaspoons ground cinnamon   1/4 teaspoon ground nutmeg   2/3 cup packed brown sugar   1 cup rolled oats   1 1/2 cups grated apple   1/4 cup chopped walnuts   1/4 cup raisins   2 eggs   1/4 cup milk   1/4 cup vegetable oil                                                                                                                     |
# |Buttermilk Oatmeal Bread           |1 cup rolled oats   1 cup buttermilk   1/2 cup vegetable oil   1 egg   1/2 cup packed brown sugar   1 cup all-purpose flour   1 teaspoon baking powder   1/2 teaspoon baking soda   1/2 teaspoon salt                                                                                                                                                                                                                                                           |
# |Kolaches II                        |1 cup shortening   1/2 cup white sugar   1 1/2 teaspoons salt   2 1/2 cups scalded milk   4 egg yolks                                                                                                                                                                                                                                                                                                                                                           |
# |Whole Wheat Bread II               |1/3 cup shortening   1 cup hot water   1 cup packed brown sugar   3 .25 ounce packages active dry yeast   4 cups warm water 110 degrees F/45 degrees C   4 tablespoons white sugar   4 teaspoons salt   6 cups bread flour   6 cups whole wheat flour                                                                                                                                                                                                           |
# |Finnish Pulla                      |2 cups milk   1/2 cup warm water 110 degrees F/45 degrees C   1 .25 ounce package active dry yeast   1 cup white sugar   1 teaspoon salt   1 teaspoon ground cardamom   4 eggs                                                                                                                                                                                                                                                                                  |
# |Chinese Steamed Buns               |1 tablespoon active dry yeast   1 teaspoon white sugar   1/4 cup all-purpose flour   1/4 cup water   1/2 cup warm water   1 1/2 cups all-purpose flour   1/4 teaspoon salt   2 tablespoons white sugar   1 tablespoon vegetable oil   1/2 teaspoon baking powder                                                                                                                                                                                                |
# |Cottage Cheese Bread II            |3/4 cup warm water 110 degrees F/45 degrees C   1 cup cottage cheese                                                                                                                                                                                                                                                                                                                                                                                            |
# |Mocha Chocolate Chip Banana Muffins|1 cup margarine   1 1/4 cups white sugar   1 egg   3 ripe bananas   1 tablespoon instant coffee granules                                                                                                                                                                                                                                                                                                                                                        |
# |Ruby's Special Cornbread           |1 cup cornmeal   1 cup milk   3 eggs   1/2 cup chopped green bell pepper   1/2 cup chopped onion   1 teaspoon garlic powder   1/2 teaspoon salt   1/2 teaspoon baking soda   1/2 teaspoon white sugar   1 8.75 ounce can whole kernel corn                                                                                                                                                                                                                      |
# |Fudgy Chocolate Chip Muffins       |(262144,[39118,100992,139051,154659,169324,249180],[1.3811078344325907,0.7038037607484741,5.339139361068292,0.9912173159222605,3.5132468854707786,0.4823604776007224])                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |Pumpernickel Bread II              |(262144,[2053,11255,12524,22285,25702,34996,36296,39118,64494,73171,92651,94567,95232,100700,100992,127347,137175,138877,140381,154659,168590,172129,172654,174319,188784,194156,194802,213712,218214,249180,250062],[4.358310108056566,3.4326880487535263,2.608788776923965,6.214608098422191,3.937340813412436,4.135166556742356,0.9733903239147279,1.3811078344325907,3.687790447297167,2.077842820316139,0.4793082068823988,1.3186357126460757,3.1304071768805923,2.2604839169754105,0.7038037607484741,3.868006120011372,4.739587685374992,6.158227764986084,1.9625477902083366,0.49560865796113024,1.4237885655474711,3.5935692743096115,1.8662675214031166,2.4640588042169225,5.690173975180047,2.4581727214025872,3.3683229172600737,2.529485693185968,3.1559010257068123,4.341244298406502,5.298317366548036])                                                                                                     |
# +-----------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
#
# +---------------------------+-----------------------------------+--------------------+
# |recipeNames                |recipeNames                        |cosine_similarity   |
# +---------------------------+-----------------------------------+--------------------+
# |Poppy Seed Bread with Glaze|Czech Christmas Hoska              |0.07343886058675417 |
# |Poppy Seed Bread with Glaze|Applesauce Bread I                 |0.321752328629361   |
# |Poppy Seed Bread with Glaze|Raisin Brown Bread                 |0.17860423764588937 |
# |Poppy Seed Bread with Glaze|Applesauce Raisin Bread            |0.35923414074129384 |
# |Poppy Seed Bread with Glaze|Apple Raisin Bread                 |0.3639985017566843  |
# |Poppy Seed Bread with Glaze|Buttermilk Oatmeal Bread           |0.28982174512782577 |
# |Poppy Seed Bread with Glaze|Kolaches II                        |0.22852130631274417 |
# |Poppy Seed Bread with Glaze|Whole Wheat Bread II               |0.1565745590250989  |
# |Poppy Seed Bread with Glaze|Finnish Pulla                      |0.11597231773742712 |
# |Poppy Seed Bread with Glaze|Chinese Steamed Buns               |0.30834977672213343 |
# |Poppy Seed Bread with Glaze|Cottage Cheese Bread II            |0.012460532808241968|
# |Poppy Seed Bread with Glaze|Mocha Chocolate Chip Banana Muffins|0.1042003497324003  |
# |Poppy Seed Bread with Glaze|Ruby's Special Cornbread           |0.21453051655803446 |
# |Poppy Seed Bread with Glaze|Maple Muffins                      |0.34806723046628724 |
# |Poppy Seed Bread with Glaze|French Toast I                     |0.16409009445581088 |
# |Poppy Seed Bread with Glaze|Snow Day French Toast              |0.19567605064904806 |
# |Poppy Seed Bread with Glaze|Angel Biscuits II                  |0.19503312993922592 |
# |Poppy Seed Bread with Glaze|Fudgy Chocolate Chip Muffins       |0.07113395456949698 |
# |Poppy Seed Bread with Glaze|Pumpernickel Bread II              |0.29170858740532857 |
# |Poppy Seed Bread with Glaze|Indian Naan II                     |0.13371893754148603 |
# +---------------------------+-----------------------------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import DoubleType
from pyspark.ml.linalg import DenseVector

# Function to compute centered cosine similarity
def centered_cosine_similarity(vec1, vec2):
    # Compute means of each vector's components
    mean_vec1 = sum(vec1) / len(vec1)
    mean_vec2 = sum(vec2) / len(vec2)

    # Center the vectors by subtracting the means
    centered_vec1 = DenseVector(vec1 - mean_vec1)
    centered_vec2 = DenseVector(vec2 - mean_vec2)

    # Compute cosine similarity between centered vectors
    dot_product = float(centered_vec1.dot(centered_vec2))
    norm_centered_vec1 = float(centered_vec1.norm(2))
    norm_centered_vec2 = float(centered_vec2.norm(2))

    return dot_product / (norm_centered_vec1 * norm_centered_vec2)

# User-defined function for centered cosine similarity
centered_cosine_similarity_udf = udf(centered_cosine_similarity, DoubleType())

# Compute centered cosine similarity between recipes
centered_cosine_similarity_result = joined_data.select(
    "df1.recipeNames",
    "df2.recipeNames",
    centered_cosine_similarity_udf("df1.features", "df2.features").alias("centered_cosine_similarity")
)

# Filter out similarity between the same recipes
centered_cosine_similarity_result = centered_cosine_similarity_result.filter("df1.recipeNames != df2.recipeNames")
centered_cosine_similarity_result.show(truncate=False)
# Out:
# +---------------------------+-----------------------------------+--------------------------+
# |recipeNames                |recipeNames                        |centered_cosine_similarity|
# +---------------------------+-----------------------------------+--------------------------+
# |Poppy Seed Bread with Glaze|Czech Christmas Hoska              |0.0733783858200811        |
# |Poppy Seed Bread with Glaze|Applesauce Bread I                 |0.3216976132627152        |
# |Poppy Seed Bread with Glaze|Raisin Brown Bread                 |0.1785376466617272        |
# |Poppy Seed Bread with Glaze|Applesauce Raisin Bread            |0.3591791595834009        |
# |Poppy Seed Bread with Glaze|Apple Raisin Bread                 |0.3639428395025738        |
# |Poppy Seed Bread with Glaze|Buttermilk Oatmeal Bread           |0.2897694619299587        |
# |Poppy Seed Bread with Glaze|Kolaches II                        |0.22847932165579546       |
# |Poppy Seed Bread with Glaze|Whole Wheat Bread II               |0.1564981269715962        |
# |Poppy Seed Bread with Glaze|Finnish Pulla                      |0.11590601351973123       |
# |Poppy Seed Bread with Glaze|Chinese Steamed Buns               |0.30829526574163457       |
# |Poppy Seed Bread with Glaze|Cottage Cheese Bread II            |0.01241140853123136       |
# |Poppy Seed Bread with Glaze|Mocha Chocolate Chip Banana Muffins|0.10414830827634798       |
# |Poppy Seed Bread with Glaze|Ruby's Special Cornbread           |0.21446742763053658       |
# |Poppy Seed Bread with Glaze|Maple Muffins                      |0.3480227595895261        |
# |Poppy Seed Bread with Glaze|French Toast I                     |0.16403620684364437       |
# |Poppy Seed Bread with Glaze|Snow Day French Toast              |0.1956252413867846        |
# |Poppy Seed Bread with Glaze|Angel Biscuits II                  |0.19496225653127913       |
# |Poppy Seed Bread with Glaze|Fudgy Chocolate Chip Muffins       |0.07110441820586826       |
# |Poppy Seed Bread with Glaze|Pumpernickel Bread II              |0.2916468209059691        |
# |Poppy Seed Bread with Glaze|Indian Naan II                     |0.13364972860967428       |
# +---------------------------+-----------------------------------+--------------------------+
# only showing top 20 rows
